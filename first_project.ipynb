# %%
import requests
import pandas as pd

"""Petfinder API to pull listings for adoptable pets."""

# Step 1: Authenticate and obtain API access token
auth_data = {
    "grant_type": "client_credentials",  # OAuth 2.0 authentication requires a "client_credentials" grant type.
    "client_id": CLIENT_ID,  # Your application's Client ID.
    "client_secret": CLIENT_SECRET  # Your application's Client Secret.
}

# %%
response = requests.post(TOKEN_URL, data=auth_data)
response
# Out:
# <Response [200]>

# %%
headers = {"Authorization": f"Bearer {access_token}"}
headers
# Out:
# {'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..F7z6iRQkqvuRjKhDAYXmLNnzR7e8KFJDnA1sID9Wzqezn5Rc7AcDTedQoC6Z6dNHX2IoWjoX-31eAw0nzToDql0l34_nKuZMh9_sZM_fqJoV7z5ob7-1ovm_pTmw5fXjRC5qYbJHoLYFf0KL15mGzcDCaA-EPQvrbmc7xnxhdiBlHLSdbvux8Mr51uoWPgupjE_GQIk2v7bsTrhqoqS10tQ9qy5-sSa1HhyPDj4LJw5aH9dbTAQYE3m4FaSLjivnZdD5IilQ6MynjB1MTh_jqPYVhgRX5DBofEPnAVUVxzE5ObgB6csDHd9BG04hl3szWvLdDIzjent9qV2lNv4drQ'}

# %%
response = requests.get(PET_URL, params=params, headers=headers) 
response
# Out:
# <Response [401]>

# %%
pet_data = response.json()
pet_data
# Out:
# {'type': 'https://httpstatus.es/401',
#  'status': 401,
#  'title': 'Unauthorized',
#  'detail': 'Access token invalid or expired'}

# %%
response = requests.post(TOKEN_URL, data=auth_data)  # Send a POST request to get an access token.
access_token = response.json()["access_token"]  # Extract the access token from the response.

# Step 2: Define headers with authentication for further requests
headers = {"Authorization": f"Bearer {access_token}"}  # Include the token in the Authorization header.

# Step 3: Fetch adoptable pets using Petfinder API
PET_URL = "https://api.petfinder.com/v2/animals"  # API endpoint to retrieve pet listings.

params = {
    "type": "dog",  # Specify the type of pet (e.g., "dog" or "cat").
    "location": "75001",  # Filter results by location (ZIP code for Paris).
      # Limit the number of results to 5 pets.
}

response = requests.get(PET_URL, params=params, headers=headers)  # Make a GET request to retrieve pet listings.

# Step 4: Check if the API request was successful
if response.status_code == 200:  # If the status code is 200, it means the request was successful.
    pet_data = response.json()  # Convert the response to JSON format.
    
    # Step 5: Iterate through the list of pets and display details
    for pet in pet_data["animals"]:
        print(f"🐶 Name: {pet['name']}")  # Print the pet's name.
        print(f"📌 Breed: {pet['breeds']['primary']}")  # Print the pet's primary breed.
        print(f"🎂 Age: {pet['age']}")  # Print the pet's age category.
        print(f"📍 Location: {pet['contact']['address']['city']}, {pet['contact']['address']['state']}")  # Print the city and state of the shelter.
        print(f"🏠 Shelter: {pet['organization_id']}")  # Print the shelter's unique ID.
        print(f"🔗 Adoption Link: {pet['url']}")  # Print the link to the pet's adoption page.
        print("-" * 40)  # Print a separator for readability.

else:  # If the request fails, display an error message.
    print(f"❌ Failed to fetch pets: {response.status_code}")  # Print the HTTP status code for debugging.
# Out:
# ❌ Failed to fetch pets: 429

# %%
# Define the organization ID (shelter ID) that you want to fetch details for.
shelter_id = "TX2896"  # Example shelter ID

# Construct the API endpoint URL to retrieve shelter details.
ORG_URL = f"https://api.petfinder.com/v2/organizations/{shelter_id}"

# Send a request to the Petfinder API using the previously obtained authentication headers.
response = requests.get(ORG_URL, headers=headers)

# Step 1: Check if the API request was successful
if response.status_code == 200:  # A status code of 200 means the request was successful.
    shelter_data = response.json()["organization"]  # Extract the organization (shelter) details from the response.
    

    # Step 2: Display key details about the shelter
    print(f"🏠 Shelter Name: {shelter_data['name']}")  # Print the name of the shelter.
    print(f"📍 Location: {shelter_data['address']['city']}, {shelter_data['address']['state']}")  # Print the city and state where the shelter is located.
    print(f"📞 Phone: {shelter_data['phone']}")  # Print the shelter’s contact phone number.
    print(f"🌍 Website: {shelter_data['url']}")  # Print the website of the shelter for more details.

# Step 3: Handle errors if the request fails
else:  # If the response status is not 200, print an error message.
    print(f"❌ Failed to fetch shelter details: {response.status_code}")  # Print the HTTP status code for debugging.
# Out:
# ❌ Failed to fetch shelter details: 429

# %%
# Exemple : obtenir les données des animaux
PET_URL = "https://api.petfinder.com/v2/animals"
params = {
    "type": "dog",
    "location": "75001",
    "limit": 100
}
response = requests.get(PET_URL, params=params, headers=headers)

if response.status_code == 200:
    data = response.json()         # La réponse entière en JSON
    pet_list = data["animals"]       # La liste des animaux (c'est déjà une liste de dictionnaires)
    
    # Utilise json_normalize pour aplatir les données imbriquées :
    df = pd.json_normalize(pet_list, sep='_')
    
    # Affiche un aperçu du DataFrame
    df.head()
else:
    print(f"❌ Failed to fetch pets: {response.status_code}")
df.head()

df.to_excel("adoptable_pets.xlsx", index=False, sheet_name="Pets")
df.to_csv("adoptable_pets.csv", index=False)
df.shape
# Out:
# ❌ Failed to fetch pets: 429
# (100, 50)

# %%
auth_data = {"grant_type": "client_credentials", "client_id": CLIENT_ID, "client_secret": CLIENT_SECRET}
response = requests.post(TOKEN_URL, data=auth_data)
access_token = response.json()["access_token"]

# Define headers with authentication
headers = {"Authorization": f"Bearer {access_token}"}

# 🐶 Fetch adoptable pets from Petfinder API
PET_URL = "https://api.petfinder.com/v2/animals"
params = {"type": "dog", "location": "75001", "limit": 5}  # Example: Dogs near Paris

response = requests.get(PET_URL, params=params, headers=headers)

if response.status_code == 200:
    pet_data = response.json()["animals"]  # Extract list of pets

    # 📊 Convert JSON response directly into DataFrame
    df_pets = pd.json_normalize(pet_data)

    # 🏗 Select and rename relevant columns
    df_pets_selected = df_pets[["name", "breeds.primary", "age", "organization_id", "url", "contact.address.city", "contact.address.state"]]
    df_pets_selected.columns = ["Name", "Breed", "Age", "Shelter ID", "Adoption Link", "City", "State"]

    print("🐶 Adoptable Pets DataFrame:")
    print(df_pets_selected.head())  # Display a preview of the pet listings

else:
    print(f"❌ Failed to fetch pets: {response.status_code}")

# 🏠 Fetch shelter details (example for one shelter)
shelter_id = "TX2896"  # Example shelter ID
ORG_URL = f"https://api.petfinder.com/v2/organizations/{shelter_id}"

response = requests.get(ORG_URL, headers=headers)
if response.status_code == 200:
    shelter_data = response.json()["organization"]

    # Convert shelter data to DataFrame
    df_shelters = pd.DataFrame([{
        "Shelter ID": shelter_data["id"],
        "Shelter Name": shelter_data["name"],
        "City": shelter_data["address"]["city"],
        "State": shelter_data["address"]["state"],
        "Phone": shelter_data["phone"],
        "Website": shelter_data["url"]
    }])

    print("\n🏠 Shelter Details DataFrame:")
    print(df_shelters.head())  # Display shelter details

else:
    print(f"❌ Failed to fetch shelter details: {response.status_code}")

# 🔗 Merge Pet & Shelter DataFrames
df_combined = df_pets_selected.merge(df_shelters, on="Shelter ID", how="left")
print("\n🔄 Merged DataFrame:")
df_combined.head()  # Display final merged data
# Out:
# ❌ Failed to fetch pets: 429
# ❌ Failed to fetch shelter details: 429
#
# 🔄 Merged DataFrame:
#             Name         Breed    Age Shelter ID  \
# 0    Little Pepe     Chihuahua  Adult     TX2896
# 1    Little Pepe     Chihuahua  Adult     TX2896
# 2         Weasel     Dachshund  Young     TX1223
# 3        Petunia         Corgi  Young     TX1223
# 4  Tori PKA Tory  Aussiedoodle  Adult     TX1568
#
#                                        Adoption Link            City_x  \
# 0  https://www.petfinder.com/dog/little-pepe-7644...              Krum
# 1  https://www.petfinder.com/dog/little-pepe-7644...  Highland Village
# 2  https://www.petfinder.com/dog/weasel-76440021/...         Arlington
# 3  https://www.petfinder.com/dog/petunia-76440020...         Arlington
# 4  https://www.petfinder.com/dog/tori-pka-tory-76...            Dallas
#
#   State_x       Shelter Name City_y State_y Phone  \
# 0      TX  Ruff Road Revival   Krum      TX  None
# ...

# %%
df_pets.to_csv("original_adoptable_pets.csv", index=False)
df_pets
# Out:
#          id organization_id  \
# 0  76440074          TX2896
# 1  76440023          TX2896
# 2  76440021          TX1223
# 3  76440020          TX1223
# 4  76438778          TX1568
#
#                                                  url type species    age  \
# 0  https://www.petfinder.com/dog/little-pepe-7644...  Dog     Dog  Adult
# 1  https://www.petfinder.com/dog/little-pepe-7644...  Dog     Dog  Adult
# 2  https://www.petfinder.com/dog/weasel-76440021/...  Dog     Dog  Young
# 3  https://www.petfinder.com/dog/petunia-76440020...  Dog     Dog  Young
# 4  https://www.petfinder.com/dog/tori-pka-tory-76...  Dog     Dog  Adult
#
#    gender   size  coat                                               tags  \
# 0    Male  Small  None  [Affectionate, Curious, Funny, Friendly, Loves...
# 1    Male  Small  None  [Affectionate, Curious, Funny, Friendly, Loves...
# 2    Male  Small  None                                                 []
# ...

# %%
df_pets.columns
# Out:
# Index(['id', 'organization_id', 'url', 'type', 'species', 'age', 'gender',
#        'size', 'coat', 'tags', 'name', 'description', 'organization_animal_id',
#        'photos', 'videos', 'status', 'status_changed_at', 'published_at',
#        'distance', 'breeds.primary', 'breeds.secondary', 'breeds.mixed',
#        'breeds.unknown', 'colors.primary', 'colors.secondary',
#        'colors.tertiary', 'attributes.spayed_neutered',
#        'attributes.house_trained', 'attributes.declawed',
#        'attributes.special_needs', 'attributes.shots_current',
#        'environment.children', 'environment.dogs', 'environment.cats',
#        'primary_photo_cropped.small', 'primary_photo_cropped.medium',
#        'primary_photo_cropped.large', 'primary_photo_cropped.full',
#        'contact.email', 'contact.phone', 'contact.address.address1',
#        'contact.address.address2', 'contact.address.city',
#        'contact.address.state', 'contact.address.postcode',
# ...

# %%
df_pets.shape
# Out:
# (5, 50)
